# %% [markdown]
# <a href="https://colab.research.google.com/github/growingwoni/hyewon2022/blob/main/%EC%8A%A4%ED%84%B0%EB%94%94%ED%94%8C%EB%9E%9C%EB%8F%84%EC%9A%B0%EB%AF%B8(%ED%98%9C%EC%9B%90).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##프로젝트 < ✍스터디 플랜 도우미 프로그램>
# ##목표: 우선순위를 고려하여 과제 계획 세우기
# ####1. 오늘 해야할 과제들을 모두 입력합니다.
# ####2. 오늘 완료할 수 있는 적절한 양인지 확인합니다. (적절하지 않다면 다시 1번 입력받기)
# ####3. 우선순위를 정합니다. (오타 또는 오늘 할 과제가 아니라면 다시 입력받기)
# ####4. 우선순위를 고려한 오늘 해야할 과제를 순서대로 표시합니다.
#
# 코드 실행 결과
#  ----------------------------------
# |  안녕하세요! [✍스터디플랜 도우미]입니다. |
#  ----------------------------------
#  오늘은 2022-08-20입니다.
#  오늘 해야할 과제들을 적어보세요.(최대 5가지 띄어쓰기X, 쉼표(,)로 구분)
# : 코딩연습하기,책읽기,운동하기,수학학습지19-20쪽,논술쓰기
#  ----------------------------------------------------
#   오늘 해야할 과제는 ['코딩연습하기', '책읽기', '운동하기', '수학학습지19-20쪽', '논술쓰기']이군요.
#  ----------------------------------------------------
# ['코딩연습하기', '책읽기', '운동하기', '수학학습지19-20쪽', '논술쓰기']는(은) 오늘 완료할 수 있는 적절한 양인가요?(네/아니오): 아니오
#  --------------------------------------
#  할 수 있는 적절한 양을 다시 생각하여 적어봅시다.
#  --------------------------------------
#  오늘은 2022-08-20입니다.
#  오늘 해야할 과제들을 적어보세요.(최대 5가지 띄어쓰기X, 쉼표(,)로 구분)
# : 코딩연습하기,책읽기,운동하기,수학학습지19-20쪽
#  ----------------------------------------------------------------------
#   오늘 해야할 과제는 ['코딩연습하기', '책읽기', '운동하기', '수학학습지19-20쪽']이군요.
#  ----------------------------------------------------------------------
# ['코딩연습하기', '책읽기', '운동하기', '수학학습지19-20쪽']는(은) 오늘 완료할 수 있는 적절한 양인가요?(네/아니오): 네
#  -----------------------
#   과제의 우선순위를 정해봅시다!
#  -----------------------
# ['코딩연습하기', '책읽기', '운동하기', '수학학습지19-20쪽']중에서 가장 먼저 해야하는 것은 무엇입니까?: 코딩연습하기
# ['책읽기', '운동하기', '수학학습지19-20쪽']중 그 다음 해야하는 것은 무엇입니까?: 수학학습지19쪽
#  -------------------------------------------------------------------
# 수학학습지19쪽는(은) 오늘 해야할 과제에 포함되지 않습니다. 다시 한 번 정확히 입력해주세요.
#  -------------------------------------------------------------------
# ['책읽기', '운동하기', '수학학습지19-20쪽']중 그 다음 해야하는 것은 무엇입니까?: 수학학습지19-20쪽
# ['책읽기', '운동하기']중 그 다음 해야하는 것은 무엇입니까?: 운동하기
#  ------------------------------------------------------------------------------------------------------
#   오늘 해야할 과제의 순서는 1. 코딩연습하기,  2. 수학학습지19-20쪽,  3. 운동하기,  4. ['책읽기']입니다. 화이팅하세요!
#  ------------------------------------------------------------------------------------------------------

# %%
from time import sleep
import datetime
import sys

dt_now = datetime.datetime.now()

print(" ---------------------------------- ")
print("|  안녕하세요! [✍스터디플랜 도우미]입니다. | ")
print(" ----------------------------------")
sleep(1)

while True: 
    task = input(' 오늘은 {}입니다.\n 오늘 해야할 과제들을 적어보세요.(최대 5가지, 띄어쓰기X, 쉼표(,)로 구분)\n: '.format(dt_now.date())).split(',')
    sleep(1)
    print(" ---------------------------------------------------- ")
    print('  오늘 해야할 과제는 '+str(task)+'이군요.')
    print(" ---------------------------------------------------- ")
    sleep(1)

    input_answer = input(str(task)+'는(은) 오늘 완료할 수 있는 적절한 양인가요?(네/아니오): ')

    if(input_answer == '네'):
        if(len(task)==1):
            sleep(1)
            print(" ---------------------------------------------------- ")
            print('  오늘 해야할 과제는'+str(task)+'입니다. 화이팅하세요!')
            print(" ---------------------------------------------------- ")
            break               

        else:
            sleep(1)
            print(" ----------------------- ")
            print('  과제의 우선순위를 정해봅시다!') 
            print(" ----------------------- ")

        
            while len(task)==2 :
                sleep(1)
                task_1 = input(str(task)+'중에서 가장 먼저 해야하는 것은 무엇입니까?: ')

                if str(task_1) in task:
                    task.remove(str(task_1))
                    sleep(1)
                    print(" ------------------------------------------------------------------------------ ")
                    print('  오늘 해야할 과제의 순서는 1. ' + str(task_1) +',  2. '+ str(task) +'입니다. 화이팅하세요!')
                    print(" ------------------------------------------------------------------------------ ")
                    sys.exit(0)
        
                elif str(task_1) not in task:
                    sleep(1)
                    print(" -------------------------------------------------------------------")
                    print(   task_1+"는(은) 오늘 해야할 과제에 포함되지 않습니다. 다시 한 번 정확히 입력해주세요.")
                    print(" -------------------------------------------------------------------")
                    task_1=[]

                
            while len(task)==3 :
                sleep(1)
                task_1 = input(str(task)+'중에서 가장 먼저 해야하는 것은 무엇입니까?: ')
                if str(task_1) in task:
                    task.remove(str(task_1))
                    sleep(1)      


                    while True: 
                        task_2 = input(str(task)+'중 그 다음 해야하는 것은 무엇입니까?: ')
                        if str(task_2) in task:
                            task.remove(str(task_2))
                            sleep(1)
                            print(" ------------------------------------------------------------------------------------------------------ ")
                            print('  오늘 해야할 과제의 순서는 1. ' + str(task_1) +',  2. '+ str(task_2) +',  3. '+ str(task) + '입니다. 화이팅하세요!')
                            print(" ------------------------------------------------------------------------------------------------------ ")
                            sys.exit(0)

                        elif str(task_2) not in task:
                            sleep(1)
                            print(" -------------------------------------------------------------------")
                            print(   task_2+"는(은) 오늘 해야할 과제에 포함되지 않습니다. 다시 한 번 정확히 입력해주세요.")
                            print(" -------------------------------------------------------------------")
                            task_2=[]

                elif str(task_1) not in task:
                    sleep(1)
                    print(" -------------------------------------------------------------------")
                    print(   task_1+"는(은) 오늘 해야할 과제에 포함되지 않습니다. 다시 한 번 정확히 입력해주세요.")
                    print(" -------------------------------------------------------------------")
                    task_1=[]                         

                                     
            while len(task)==4 :
                sleep(1)
                task_1 = input(str(task)+'중에서 가장 먼저 해야하는 것은 무엇입니까?: ')
                if str(task_1) in task:
                    task.remove(str(task_1))
                    sleep(1)

                    while True: 
                        task_2 = input(str(task)+'중 그 다음 해야하는 것은 무엇입니까?: ')
                        if str(task_2) in task:
                            task.remove(str(task_2))
                            sleep(1)

                            while True:
                                task_3 = input(str(task)+'중 그 다음 해야하는 것은 무엇입니까?: ')
                                if str(task_3) in task:
                                    task.remove(str(task_3))
                                    sleep(1)                           
                                    print(" ------------------------------------------------------------------------------------------------------ ")
                                    print('  오늘 해야할 과제의 순서는 1. ' + str(task_1) +',  2. '+ str(task_2) +',  3. '+ str(task_3) +',  4. '+ str(task) +'입니다. 화이팅하세요!')
                                    print(" ------------------------------------------------------------------------------------------------------ ")
                                    sys.exit(0)

                                elif str(task_3) not in task:
                                    sleep(1)
                                    print(" -------------------------------------------------------------------")
                                    print(   task_3+"는(은) 오늘 해야할 과제에 포함되지 않습니다. 다시 한 번 정확히 입력해주세요.")
                                    print(" -------------------------------------------------------------------")
                                    task_3=[] 

                        elif str(task_2) not in task:
                            sleep(1)
                            print(" -------------------------------------------------------------------")
                            print(   task_2+"는(은) 오늘 해야할 과제에 포함되지 않습니다. 다시 한 번 정확히 입력해주세요.")
                            print(" -------------------------------------------------------------------")
                            task_2=[]   

                elif str(task_1) not in task:
                    sleep(1)
                    print(" -------------------------------------------------------------------")
                    print(   task_1+"는(은) 오늘 해야할 과제에 포함되지 않습니다. 다시 한 번 정확히 입력해주세요.")
                    print(" -------------------------------------------------------------------")
                    task_1=[]  


            while len(task)==5 :
                sleep(1)
                task_1 = input(str(task)+'중에서 가장 먼저 해야하는 것은 무엇입니까?: ')                
                if str(task_1) in task:
                    task.remove(str(task_1))
                    sleep(1)
                
                    while True:
                        task_2 = input(str(task)+'중 그 다음 해야하는 것은 무엇입니까?: ')
                        if str(task_2) in task:
                            task.remove(str(task_2))
                            sleep(1)

                            while True:                              
                                task_3 = input(str(task)+'중 그 다음 해야하는 것은 무엇입니까?: ')
                                if str(task_3) in task:
                                    task.remove(str(task_3))
                                    sleep(1) 

                                    while True:
                                        task_4 = input(str(task)+'중 그 다음 해야하는 것은 무엇입니까?: ')
                                        if str(task_4) in task:
                                          task.remove(str(task_4))
                                          task_5 = str(task)
                                          sleep(1)
                                          print(" --------------------------------------------------------------------------------------------------------------------------------------- ")
                                          print('  오늘 해야할 과제의 순서는 1. ' + str(task_1) +',  2. '+ str(task_2) +',  3. '+ str(task_3) +',  4. '+ str(task_4) +',  5. '+ str(task_5) +'입니다. 화이팅하세요!')
                                          print(" --------------------------------------------------------------------------------------------------------------------------------------- ")
                                          sys.exit(0)

                                        elif str(task_4) not in task:
                                          sleep(1)
                                          print(" -------------------------------------------------------------------")
                                          print(   task_4+"는(은) 오늘 해야할 과제에 포함되지 않습니다. 다시 한 번 정확히 입력해주세요.")
                                          print(" -------------------------------------------------------------------")
                                             

                                elif str(task_3) not in task:
                                    sleep(1)
                                    print(" -------------------------------------------------------------------")
                                    print(   task_3+"는(은) 오늘 해야할 과제에 포함되지 않습니다. 다시 한 번 정확히 입력해주세요.")
                                    print(" -------------------------------------------------------------------")
                                       

                        elif str(task_2) not in task:
                            sleep(1)
                            print(" -------------------------------------------------------------------")
                            print(   task_2+"는(은) 오늘 해야할 과제에 포함되지 않습니다. 다시 한 번 정확히 입력해주세요.")
                            print(" -------------------------------------------------------------------")
                        
                                               
                elif str(task_1) not in task:
                    sleep(1)
                    print(" -------------------------------------------------------------------")
                    print(   task_1+"는(은) 오늘 해야할 과제에 포함되지 않습니다. 다시 한 번 정확히 입력해주세요.")
                    print(" -------------------------------------------------------------------")
                     
                   
                      
    elif input_answer == '아니오' :
        sleep(2)
        print(" --------------------------------------")
        print(' 할 수 있는 적절한 양을 다시 생각하여 적어봅시다.')
        print(" --------------------------------------")
# Out:
#  ----------------------------------
# |  안녕하세요! [✍스터디플랜 도우미]입니다. |
#  ----------------------------------
#  오늘은 2022-08-20입니다.
#  띄어쓰기X, 쉼표(,)로 구분)
# : 코딩연습하기,책읽기,운동하기,수학학습지19-20쪽,논술쓰기
#  ----------------------------------------------------
#   오늘 해야할 과제는 ['코딩연습하기', '책읽기', '운동하기', '수학학습지19-20쪽', '논술쓰기']이군요.
#  ----------------------------------------------------
# ['코딩연습하기', '책읽기', '운동하기', '수학학습지19-20쪽', '논술쓰기']는(은) 오늘 완료할 수 있는 적절한 양인가요?(네/아니오): 아니오
#  --------------------------------------
#  할 수 있는 적절한 양을 다시 생각하여 적어봅시다.
#  --------------------------------------
#  오늘은 2022-08-20입니다.
#  띄어쓰기X, 쉼표(,)로 구분)
# : 코딩연습하기,책읽기,운동하기,수학학습지19-20쪽
#  ----------------------------------------------------
#   오늘 해야할 과제는 ['코딩연습하기', '책읽기', '운동하기', '수학학습지19-20쪽']이군요.
#  ----------------------------------------------------
# ['코딩연습하기', '책읽기', '운동하기', '수학학습지19-20쪽']는(은) 오늘 완료할 수 있는 적절한 양인가요?(네/아니오): 네
#  -----------------------
#   과제의 우선순위를 정해봅시다!
#  -----------------------
# ...
